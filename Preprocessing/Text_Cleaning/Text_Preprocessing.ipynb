# %% [markdown]
# # Simple example of reading a web page and converting it to plain text
# How the code works:
# * package **requests** is used to load web page from URL given in variable *documentURL*
# * package **BeautifulSoup4 (bs4)** is used to parse content of loaded web page
# * the call of *soup.get_text()* in the last line provides the content of page as plain text

# %%
import pandas as pd

# %%
df_data = pd.read_csv('SampleData.csv') #Read the data from the previous step of XML Parsing.

# %%
df_data #Read it into a pandas dataframe.
# Out:
#                      from                    to  \
# 0  dummyfrom1@rabobank.nl  dummyto1@rabobank.nl
# 1  dummyfrom2@rabobank.nl  dummyto2@rabobank.nl
# 2  dummyfrom7@rabobank.nl  dummyto7@rabobank.nl
# 3  dummyfrom0@rabobank.nl  dummyto0@rabobank.nl
# 4  dummyfrom9@rabobank.nl  dummyto9@rabobank.nl
# 5  dummyfrom4@rabobank.nl  dummyto4@rabobank.nl
# 6  dummyfrom3@rabobank.nl  dummyto3@rabobank.nl
# 7  dummyfrom6@rabobank.nl  dummyto6@rabobank.nl
#
#                            subject  \
# 0   Dummy Subject for this email 1
# 1   Dummy Subject for this email 2
# 2   Dummy Subject for this email 7
# 3   Dummy Subject for this email 0
# 4   Dummy Subject for this email 9
# 5   Dummy Subject for this email 4
# 6   Dummy Subject for this email 3
# 7  Dummy Subject for this email  6
#
#                                                 body
# 0  \nNieuw-Vennep 24-09-2018.\n\nGoedemorgen ik h...
# 1  \nGoedemorgen heer, mevrouw, \n\nConform het t...
# 2  \nGeachte heer, mevrouw,\n\nNaar aanleiding va...
# 3  \nHello, \nMy mother, Frans MARLIER want to tr...
# 4  \nHi again! \nI want to confirm that you can c...
# 5  \nGeachte heer, mevrouw, \nIn verband met de a...
# 6  \nGoedemorgen, \n\nIk ben de wettelijk vertege...
# 7  \nBeste \n\nIk heb enige tijd geleden een schr...

# %%
from googletrans import Translator #googletrans library is used for translating the engish text to dutch.

# %%
translator = Translator()

# %%
df_data["input_data"] = "" #Added a new column to just store the pre-processed data

# %%
df_data
# Out:
#                      from                    to  \
# 0  dummyfrom1@rabobank.nl  dummyto1@rabobank.nl
# 1  dummyfrom2@rabobank.nl  dummyto2@rabobank.nl
# 2  dummyfrom7@rabobank.nl  dummyto7@rabobank.nl
# 3  dummyfrom0@rabobank.nl  dummyto0@rabobank.nl
# 4  dummyfrom9@rabobank.nl  dummyto9@rabobank.nl
# 5  dummyfrom4@rabobank.nl  dummyto4@rabobank.nl
# 6  dummyfrom3@rabobank.nl  dummyto3@rabobank.nl
# 7  dummyfrom6@rabobank.nl  dummyto6@rabobank.nl
#
#                            subject  \
# 0   Dummy Subject for this email 1
# 1   Dummy Subject for this email 2
# 2   Dummy Subject for this email 7
# 3   Dummy Subject for this email 0
# 4   Dummy Subject for this email 9
# 5   Dummy Subject for this email 4
# 6   Dummy Subject for this email 3
# 7  Dummy Subject for this email  6
#
#                                                 body input_data
# 0  \nNieuw-Vennep 24-09-2018.\n\nGoedemorgen ik h...
# 1  \nGoedemorgen heer, mevrouw, \n\nConform het t...
# 2  \nGeachte heer, mevrouw,\n\nNaar aanleiding va...
# 3  \nHello, \nMy mother, Frans MARLIER want to tr...
# 4  \nHi again! \nI want to confirm that you can c...
# 5  \nGeachte heer, mevrouw, \nIn verband met de a...
# 6  \nGoedemorgen, \n\nIk ben de wettelijk vertege...
# 7  \nBeste \n\nIk heb enige tijd geleden een schr...

# %%
#This for loop removes all the \n\r characters and replace them with a ' '. This enables the translate function to work properly.
for index, row in df_data.iterrows():
    
    text_to_translate = df_data.iloc[index]['body']
    text_to_translate = text_to_translate.replace('\r', ' ').replace('\n', ' ')
    text_converted = translator.translate(text_to_translate, dest='nl', src='en')
    df_data.iloc[index]['input_data'] = text_converted.text
    print ("Done!")
# Out:
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!

# %%
df_data #Now Input_data contains the tranlsated texts.
# Out:
#                      from                    to  \
# 0  dummyfrom1@rabobank.nl  dummyto1@rabobank.nl
# 1  dummyfrom2@rabobank.nl  dummyto2@rabobank.nl
# 2  dummyfrom7@rabobank.nl  dummyto7@rabobank.nl
# 3  dummyfrom0@rabobank.nl  dummyto0@rabobank.nl
# 4  dummyfrom9@rabobank.nl  dummyto9@rabobank.nl
# 5  dummyfrom4@rabobank.nl  dummyto4@rabobank.nl
# 6  dummyfrom3@rabobank.nl  dummyto3@rabobank.nl
# 7  dummyfrom6@rabobank.nl  dummyto6@rabobank.nl
#
#                            subject  \
# 0   Dummy Subject for this email 1
# 1   Dummy Subject for this email 2
# 2   Dummy Subject for this email 7
# 3   Dummy Subject for this email 0
# 4   Dummy Subject for this email 9
# 5   Dummy Subject for this email 4
# 6   Dummy Subject for this email 3
# 7  Dummy Subject for this email  6
#
#                                                 body  \
# 0  \nNieuw-Vennep 24-09-2018.\n\nGoedemorgen ik h...
# 1  \nGoedemorgen heer, mevrouw, \n\nConform het t...
# 2  \nGeachte heer, mevrouw,\n\nNaar aanleiding va...
# 3  \nHello, \nMy mother, Frans MARLIER want to tr...
# 4  \nHi again! \nI want to confirm that you can c...
# 5  \nGeachte heer, mevrouw, \nIn verband met de a...
# 6  \nGoedemorgen, \n\nIk ben de wettelijk vertege...
# 7  \nBeste \n\nIk heb enige tijd geleden een schr...
#
#                                           input_data
# 0  Nieuw-Vennep 24-09-2018. Goedemorgen ik heb 18...
# 1  Goedemorgen heer, mevrouw, Conform het telefon...
# 2  Geachte heer, mevrouw, Naar aanleiding van tel...
# 3  Hallo, mijn moeder, Frans MARLIER wil alle bes...
# 4  Hallo opnieuw! Ik wil bevestigen dat je mijn a...
# 5  Geachte heer, mevrouw, In verband met de afwik...
# 6  Goedemorgen, Ik ben de wettelijke vertegenwoor...
# 7  Beste Ik heb enige tijd geleden at not least. ...

# %%
#Testing to remove some common greetings from the email. Need to build on it.
greetings = ['Met vriendelijke groeten','Met vriendelijke groet','Bij voorbaat dank','Met vriendelijke groete--------
Not Found
Found
Not Found
Not Found
Done!
--------
Not Found
Found
Not Found
Not Found
Done!
--------
Not Found
Not Found
Not Found
Not Found
Done!
n']

# %%
#This code replaces the existing input_body column with the updated emails (removed the text after the greetings + the greetings itself)
#Need to build more to this.

for index, row in df_data.iterrows():
    x = df_data.iloc[index]['input_data']
    for i in greetings:
        
        if x.find(i) == -1:
            print ("Not Found")
        else:
            print("Found")
            head, sep, tail = x.partition(i)
            x_head = head
            df_data.iloc[index]['input_data'] = x_head
    print ("Done!")
    print ("--------")
# Out:
# Not Found
# Found
# Not Found
# Not Found
# Done!
# --------
# Not Found
# Found
# Not Found
# Not Found
# Done!
# --------
# Found
# Found
# Not Found
# Found
# Done!
# --------
# Not Found
# Not Found
# Found
# Not Found
# Done!
# --------
# Found
# Found
# Not Found
# Found
# Done!
# --------
# Not Found
# Found
# Not Found
# Not Found
# Done!
# --------
# Not Found
# Found
# Not Found
# Not Found
# Done!
# --------
# Not Found
# Not Found
# Not Found
# Not Found
# Done!
# --------

# %%
df_data #Dataframe after removing the signatures.
# Out:
#                      from                    to  \
# 0  dummyfrom1@rabobank.nl  dummyto1@rabobank.nl
# 1  dummyfrom2@rabobank.nl  dummyto2@rabobank.nl
# 2  dummyfrom7@rabobank.nl  dummyto7@rabobank.nl
# 3  dummyfrom0@rabobank.nl  dummyto0@rabobank.nl
# 4  dummyfrom9@rabobank.nl  dummyto9@rabobank.nl
# 5  dummyfrom4@rabobank.nl  dummyto4@rabobank.nl
# 6  dummyfrom3@rabobank.nl  dummyto3@rabobank.nl
# 7  dummyfrom6@rabobank.nl  dummyto6@rabobank.nl
#
#                            subject  \
# 0   Dummy Subject for this email 1
# 1   Dummy Subject for this email 2
# 2   Dummy Subject for this email 7
# 3   Dummy Subject for this email 0
# 4   Dummy Subject for this email 9
# 5   Dummy Subject for this email 4
# 6   Dummy Subject for this email 3
# 7  Dummy Subject for this email  6
#
#                                                 body  \
# 0  \nNieuw-Vennep 24-09-2018.\n\nGoedemorgen ik h...
# 1  \nGoedemorgen heer, mevrouw, \n\nConform het t...
# 2  \nGeachte heer, mevrouw,\n\nNaar aanleiding va...
# 3  \nHello, \nMy mother, Frans MARLIER want to tr...
# 4  \nHi again! \nI want to confirm that you can c...
# 5  \nGeachte heer, mevrouw, \nIn verband met de a...
# 6  \nGoedemorgen, \n\nIk ben de wettelijk vertege...
# 7  \nBeste \n\nIk heb enige tijd geleden een schr...
#
#                                           input_data
# 0  Nieuw-Vennep 24-09-2018. Goedemorgen ik heb 18...
# 1  Goedemorgen heer, mevrouw, Conform het telefon...
# 2  Geachte heer, mevrouw, Naar aanleiding van tel...
# 3  Hallo, mijn moeder, Frans MARLIER wil alle bes...
# 4  Hallo opnieuw! Ik wil bevestigen dat je mijn a...
# 5  Geachte heer, mevrouw, In verband met de afwik...
# 6  Goedemorgen, Ik ben de wettelijke vertegenwoor...
# 7  Beste Ik heb enige tijd geleden at not least. ...

# %%
df_data.to_csv("Sample_Data_2.csv") #New Sample Data
